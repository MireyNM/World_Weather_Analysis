# %%
# Import the dependencies.
# To read our CSV file and create the locations and measurements from the DataFrame
import pandas as pd

# gmaps and the API key to create heatmaps and the locations map
import gmaps

# The requests dependency to make a request to the Google Places JSON file
import requests

# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID       City Country                 Date      Lat       Lng  \
# 0        0     Matara      LK  2022-09-28 06:31:58   5.9485   80.5353
# 1        1  Cape Town      ZA  2022-09-28 06:30:48 -33.9258   18.4232
# 2        2   Victoria      HK  2022-09-28 06:29:46  22.2855  114.1577
# 3        3    Vylkove      UA  2022-09-28 06:31:59  45.4021   29.5860
# 4        4     Vanimo      PG  2022-09-28 06:31:59  -2.6741  141.3028
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     86.38        61          14       14.54
# 1     61.09        84           0        3.44
# 2     89.96        69          92       17.00
# 3     67.66        64           0       15.28
# 4     81.81        79         100        6.11

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# **N.B.:** The data we use for any mapping must be either an integer or a floating-point decimal number
#
# ## Create a Maximum Temperature Heatmap

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]

# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))


# Assign the figure variable.
fig = gmaps.figure()

# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)

# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]

# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]

# Assign the figure variable.
# fig = gmaps.fifure()
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations,
                                 weights=[max(temp, 0) for temp in max_temp],
                                 dissipating=False, 
                                 max_intensity=300, 
                                 point_radius=4)

# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a Percent Humidity Heatmap

# %%
# Heatmap of humidity

# Get the Humidity 
humidity= city_data_df["Humidity"]

# Assign the figure variable.
# fig = gmaps.fifure()
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations,
                                 weights=humidity,
                                 dissipating=False, 
                                 max_intensity=300, 
                                 point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a Percent Cloudiness Heatmap

# %%
# Heatmap of humidity

# Get the Humidity 
clouds= city_data_df["Cloudiness"]

# Assign the figure variable.
# fig = gmaps.fifure()
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations,
                                 weights=clouds,
                                 dissipating=False, 
                                 max_intensity=300, 
                                 point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a Wind Speed Heatmap

# %%
# Heatmap of humidity

# Get the Humidity 
winds= city_data_df["Wind Speed"]

# Assign the figure variable.
# fig = gmaps.fifure()
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations,
                                 weights=winds,
                                 max_intensity=300,
                                 dissipating=False,
                                 point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
min_temp
# Out:
# 70.0

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df=city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) & \
                                    (city_data_df["Max Temp"]<max_temp)]
preferred_cities_df
# Out:
#      City_ID         City Country                 Date      Lat       Lng  \
# 0          0       Matara      LK  2022-09-28 06:31:58   5.9485   80.5353
# 2          2     Victoria      HK  2022-09-28 06:29:46  22.2855  114.1577
# 4          4       Vanimo      PG  2022-09-28 06:31:59  -2.6741  141.3028
# 7          7         Hami      CN  2022-09-28 06:32:01  42.8000   93.4500
# 10        10       Itoman      JP  2022-09-28 06:32:02  26.1247  127.6694
# ..       ...          ...     ...                  ...      ...       ...
# 566      566        Hobyo      SO  2022-09-28 06:44:59   5.3505   48.5268
# 568      568       Moerai      PF  2022-09-28 06:45:00 -22.4333 -151.3333
# 569      569       Shingu      JP  2022-09-28 06:45:00  33.7333  135.9833
# 570      570  Bodden Town      KY  2022-09-28 06:45:00  19.2833  -81.2500
# 573      573      Eenhana     NaN  2022-09-28 06:45:02 -17.4667   16.3333
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# ...

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       5
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
preferred_cities_df.count()
# Out:
# City_ID       253
# City          253
# Country       248
# Date          253
# Lat           253
# Lng           253
# Max Temp      253
# Humidity      253
# Cloudiness    253
# Wind Speed    253
# dtype: int64

# %%
preferred_cities_df.notnull().sum()
# Out:
# City_ID       253
# City          253
# Country       248
# Date          253
# Lat           253
# Lng           253
# Max Temp      253
# Humidity      253
# Cloudiness    253
# Wind Speed    253
# dtype: int64

# %%
cleaned_cities_df= preferred_cities_df.dropna()
cleaned_cities_df
# Out:
#      City_ID         City Country                 Date      Lat       Lng  \
# 0          0       Matara      LK  2022-09-28 06:31:58   5.9485   80.5353
# 2          2     Victoria      HK  2022-09-28 06:29:46  22.2855  114.1577
# 4          4       Vanimo      PG  2022-09-28 06:31:59  -2.6741  141.3028
# 7          7         Hami      CN  2022-09-28 06:32:01  42.8000   93.4500
# 10        10       Itoman      JP  2022-09-28 06:32:02  26.1247  127.6694
# ..       ...          ...     ...                  ...      ...       ...
# 564      564         Tual      ID  2022-09-28 06:44:59  -5.6667  132.7500
# 566      566        Hobyo      SO  2022-09-28 06:44:59   5.3505   48.5268
# 568      568       Moerai      PF  2022-09-28 06:45:00 -22.4333 -151.3333
# 569      569       Shingu      JP  2022-09-28 06:45:00  33.7333  135.9833
# 570      570  Bodden Town      KY  2022-09-28 06:45:00  19.2833  -81.2500
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# ...

# %%
cleaned_cities_df.count()
# Out:
# City_ID       248
# City          248
# Country       248
# Date          248
# Lat           248
# Lng           248
# Max Temp      248
# Humidity      248
# Cloudiness    248
# Wind Speed    248
# dtype: int64

# %% [markdown]
# ### Get Travel Destinations

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = cleaned_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#            City Country  Max Temp      Lat       Lng Hotel Name
# 0        Matara      LK     86.38   5.9485   80.5353
# 2      Victoria      HK     89.96  22.2855  114.1577
# 4        Vanimo      PG     81.81  -2.6741  141.3028
# 7          Hami      CN     83.01  42.8000   93.4500
# 10       Itoman      JP     88.57  26.1247  127.6694
# 13      Rikitea      PF     70.36 -23.1203 -134.9692
# 17    Hithadhoo      MV     77.65  -0.6000   73.0833
# 19    Busselton      AU     70.43 -33.6500  115.3333
# 21        Kapaa      US     79.12  22.0752 -159.3190
# 22  Corn Island      NI     82.42  12.1694  -83.0418

# %% [raw]
# ### Retrieve Hotels from a Nearby Search
# **Set the Parameters for a Nearby Search** <br/>
# Nearby Search Requests is an HTTP URL of the following form: <br/>
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json" <br/>
#
# If we check types (https://developers.google.com/maps/documentation/places/web-service/supported_types) we don't find hotels but we find lodging, so we're gonna use it in our parameters.

# %%
# Use base URL to search for hotels in Paris
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Set parameters to search for a hotel.
params = { 
    "location": "48.8566, 2.3522",
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcYSjRjJ3unU3hNsOTky1_F0RKFAFscKOu87H7woRK8dS0HFeioXGXX-Vg4_FyjTpaIVe0lSe2nabBemLuZ8V7QbLQQTHneT23Tc3jLyjFCZrW_noLpwY69Tqc75-sh3d8KfHo88o8OnzX5Yifay3q-L8XIahy8dH6b0ZpJmAbriM0rBE1_qC34HZmvR1u3hvPZpaK9G3_ykUUtIBFgDVVsMr7HvBpezILPMkyrDxem8n2PbC52XVWrCeZCSopbOXTFJig4ZgERujNziSdlEyoWyLcGcArZe3xWJwu659Hu2B4IE8TIe90cmhVktdkc0vG4iDq8uDADkU5dLEa8bOiIalMxMeSqwDfJdy2xjX1x-NaKyA3O7Lk3345mzlU2FUNyFJlj8_rM-jE8rs346l7CE2_7U9zrWDbOT928nuRqP7RvFwZpsEM8O8tYz',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...

# %% [markdown]
# #https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362&radius=500&types=food&name=harbour&key=YOUR_API_KEY
#
# parameters={
#             "radius": 5000,
#              "types":"lodging",
#               "name":"harbour",
#                "key": g_key}
#
# r = requests.get(base_url, params=parameters)

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'

# %% [markdown]
# ### Iterate Through hotel_df DataFrame

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    try:
        # Grab the first hotel from the results and store the name.
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head()
# Out:
#         City Country  Max Temp      Lat       Lng  \
# 0     Matara      LK     86.38   5.9485   80.5353
# 2   Victoria      HK     89.96  22.2855  114.1577
# 4     Vanimo      PG     81.81  -2.6741  141.3028
# 7       Hami      CN     83.01  42.8000   93.4500
# 10    Itoman      JP     88.57  26.1247  127.6694
#
#                                Hotel Name
# 0                  Amaloh Boutique Resort
# 2                            Mini Central
# 4                   Vahmoneh Lodge Vanimo
# 7                        Laoyutang Resort
# 10  Southern Beach Hotel & Resort Okinawa

# %% [markdown]
# ### Create a Maximum Temperature Heatmap from a Hotel DataFrame

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

heat_layer = gmaps.heatmap_layer(locations, 
                                 weights=max_temp, 
                                 dissipating=False,
                                max_intensity=300, 
                                 point_radius=4)

fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# **Add a pop-up marker for each city that displays the hotel name, city name, country, and maximum temperature.**

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %% [markdown]
# Add the info vox content to the plot:

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
