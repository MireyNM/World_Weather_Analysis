# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 742

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b5ed7a13378f8b7c46aaedb980e7c222

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_weather_description = city_weather["weather"][0]["description"]  
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | harper
# Processing Record 3 of Set 1 | panipat
# Processing Record 4 of Set 1 | nuevo progreso
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | ayan
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | jawhar
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | mumford
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | lata
# Processing Record 18 of Set 1 | george town
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | tazovskiy
# Processing Record 23 of Set 1 | airai
# Processing Record 24 of Set 1 | asekeyevo
# Processing Record 25 of Set 1 | oriximina
# Processing Record 26 of Set 1 | rio grande
# Processing Record 27 of Set 1 | sovetskiy
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | geraldton
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | gornopravdinsk
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | ous
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | petropavlovka
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | nexo
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | kaitangata
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | sangar
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | comodoro rivadavia
# Processing Record 4 of Set 2 | tatarsk
# Processing Record 5 of Set 2 | odweyne
# Processing Record 6 of Set 2 | dukat
# Processing Record 7 of Set 2 | nome
# Processing Record 8 of Set 2 | kutum
# Processing Record 9 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 2 | alyangula
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | nelson bay
# Processing Record 14 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | changde
# Processing Record 19 of Set 2 | kaka
# Processing Record 20 of Set 2 | rio gallegos
# Processing Record 21 of Set 2 | pringsewu
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | merauke
# Processing Record 25 of Set 2 | hami
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | chizhou
# Processing Record 28 of Set 2 | sao jose da coroa grande
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | pozo colorado
# Processing Record 32 of Set 2 | prince rupert
# Processing Record 33 of Set 2 | tukrah
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | matamoros
# Processing Record 37 of Set 2 | chumikan
# Processing Record 38 of Set 2 | yumen
# Processing Record 39 of Set 2 | camacha
# Processing Record 40 of Set 2 | cayhagan
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | san francisco
# Processing Record 45 of Set 2 | linqiong
# Processing Record 46 of Set 2 | westport
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | khasan
# Processing Record 50 of Set 2 | narsaq
# Processing Record 1 of Set 3 | san andres
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | srednekolymsk
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | ustye
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | casablanca
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | boyolangu
# Processing Record 10 of Set 3 | kirkenaer
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | praya
# Processing Record 13 of Set 3 | burnie
# Processing Record 14 of Set 3 | torbay
# Processing Record 15 of Set 3 | la rioja
# Processing Record 16 of Set 3 | ewa beach
# Processing Record 17 of Set 3 | te anau
# Processing Record 18 of Set 3 | tilichiki
# Processing Record 19 of Set 3 | kavaratti
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | lagoa
# Processing Record 24 of Set 3 | pasni
# Processing Record 25 of Set 3 | port alfred
# Processing Record 26 of Set 3 | roma
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | luderitz
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | tabou
# Processing Record 31 of Set 3 | fairbanks
# Processing Record 32 of Set 3 | deputatskiy
# Processing Record 33 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 3 | vila velha
# Processing Record 35 of Set 3 | adrar
# Processing Record 36 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | combita
# Processing Record 39 of Set 3 | saint albans
# Processing Record 40 of Set 3 | troitskoye
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | hasaki
# Processing Record 43 of Set 3 | castro verde
# Processing Record 44 of Set 3 | hilo
# Processing Record 45 of Set 3 | labuhan
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | tanete
# Processing Record 48 of Set 3 | fort nelson
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | kloulklubed
# Processing Record 1 of Set 4 | koscierzyna
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | cerrito
# Processing Record 4 of Set 4 | pokhara
# Processing Record 5 of Set 4 | humberto de campos
# Processing Record 6 of Set 4 | kodinsk
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | manyana
# Processing Record 9 of Set 4 | samarai
# Processing Record 10 of Set 4 | berlevag
# Processing Record 11 of Set 4 | gizo
# Processing Record 12 of Set 4 | truth or consequences
# Processing Record 13 of Set 4 | vaitape
# Processing Record 14 of Set 4 | coihaique
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | karratha
# Processing Record 17 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 4 | pokosnoye
# Processing Record 19 of Set 4 | pandan
# Processing Record 20 of Set 4 | port hedland
# Processing Record 21 of Set 4 | nara
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | saint-joseph
# Processing Record 28 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 4 | taoudenni
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | birjand
# Processing Record 32 of Set 4 | michigan city
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | jiazi
# Processing Record 35 of Set 4 | high level
# Processing Record 36 of Set 4 | jalu
# Processing Record 37 of Set 4 | salalah
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | mogzon
# Processing Record 40 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 4 | buala
# Processing Record 42 of Set 4 | riisipere
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | ciechanow
# Processing Record 45 of Set 4 | killarney
# Processing Record 46 of Set 4 | west bay
# Processing Record 47 of Set 4 | kanodar
# Processing Record 48 of Set 4 | heyang
# Processing Record 49 of Set 4 | sept-iles
# Processing Record 50 of Set 4 | sola
# Processing Record 1 of Set 5 | mitsamiouli
# Processing Record 2 of Set 5 | monterey
# Processing Record 3 of Set 5 | lompoc
# Processing Record 4 of Set 5 | menongue
# Processing Record 5 of Set 5 | wanning
# Processing Record 6 of Set 5 | east london
# Processing Record 7 of Set 5 | kollumerland
# City not found. Skipping...
# Processing Record 8 of Set 5 | mehamn
# Processing Record 9 of Set 5 | qaqortoq
# Processing Record 10 of Set 5 | constitucion
# Processing Record 11 of Set 5 | rakhya
# City not found. Skipping...
# Processing Record 12 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 5 | upernavik
# Processing Record 14 of Set 5 | torata
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | esperance
# Processing Record 17 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 5 | bonfim
# Processing Record 19 of Set 5 | ewo
# Processing Record 20 of Set 5 | antanifotsy
# Processing Record 21 of Set 5 | butajira
# Processing Record 22 of Set 5 | noumea
# Processing Record 23 of Set 5 | praia
# Processing Record 24 of Set 5 | clyde river
# Processing Record 25 of Set 5 | surat thani
# Processing Record 26 of Set 5 | hovd
# Processing Record 27 of Set 5 | ola
# Processing Record 28 of Set 5 | itarema
# Processing Record 29 of Set 5 | monrovia
# Processing Record 30 of Set 5 | tabukiniberu
# City not found. Skipping...
# Processing Record 31 of Set 5 | mangla
# Processing Record 32 of Set 5 | jackson
# Processing Record 33 of Set 5 | iracoubo
# Processing Record 34 of Set 5 | najran
# Processing Record 35 of Set 5 | katsuura
# Processing Record 36 of Set 5 | beringovskiy
# Processing Record 37 of Set 5 | samarinda
# Processing Record 38 of Set 5 | ribeira grande
# Processing Record 39 of Set 5 | lazaro cardenas
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | necochea
# Processing Record 45 of Set 5 | udachnyy
# Processing Record 46 of Set 5 | aswan
# Processing Record 47 of Set 5 | leshukonskoye
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | coahuayana
# Processing Record 50 of Set 5 | williston
# Processing Record 1 of Set 6 | aden
# Processing Record 2 of Set 6 | esmeraldas
# Processing Record 3 of Set 6 | lakes entrance
# Processing Record 4 of Set 6 | port-gentil
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | fuerte olimpo
# Processing Record 7 of Set 6 | pierre
# Processing Record 8 of Set 6 | kirkuk
# Processing Record 9 of Set 6 | minab
# Processing Record 10 of Set 6 | new norfolk
# Processing Record 11 of Set 6 | baglan
# Processing Record 12 of Set 6 | batemans bay
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | baykit
# Processing Record 15 of Set 6 | mayumba
# Processing Record 16 of Set 6 | vestmannaeyjar
# Processing Record 17 of Set 6 | port lincoln
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 20 of Set 6 | santa rosa
# Processing Record 21 of Set 6 | bubaque
# Processing Record 22 of Set 6 | svetlogorsk
# Processing Record 23 of Set 6 | havre-saint-pierre
# Processing Record 24 of Set 6 | egyek
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 27 of Set 6 | lasa
# Processing Record 28 of Set 6 | namibe
# Processing Record 29 of Set 6 | mirnyy
# Processing Record 30 of Set 6 | hermiston
# Processing Record 31 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 33 of Set 6 | palmer
# Processing Record 34 of Set 6 | ahipara
# Processing Record 35 of Set 6 | huautla
# Processing Record 36 of Set 6 | saint-pierre
# Processing Record 37 of Set 6 | moron
# Processing Record 38 of Set 6 | obo
# Processing Record 39 of Set 6 | londonderry
# Processing Record 40 of Set 6 | half moon bay
# Processing Record 41 of Set 6 | lubango
# Processing Record 42 of Set 6 | eureka
# Processing Record 43 of Set 6 | isangel
# Processing Record 44 of Set 6 | sokoni
# Processing Record 45 of Set 6 | jhang
# Processing Record 46 of Set 6 | mecca
# Processing Record 47 of Set 6 | sechelt
# Processing Record 48 of Set 6 | pisco
# Processing Record 49 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 6 | opuwo
# Processing Record 1 of Set 7 | kununurra
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | muli
# Processing Record 4 of Set 7 | wewak
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 7 | teya
# Processing Record 9 of Set 7 | ghelinta
# Processing Record 10 of Set 7 | gat
# Processing Record 11 of Set 7 | bartica
# Processing Record 12 of Set 7 | kruisfontein
# Processing Record 13 of Set 7 | belmonte
# Processing Record 14 of Set 7 | hambantota
# Processing Record 15 of Set 7 | novouzensk
# Processing Record 16 of Set 7 | mandera
# Processing Record 17 of Set 7 | north bend
# Processing Record 18 of Set 7 | buraydah
# Processing Record 19 of Set 7 | kurovskoye
# Processing Record 20 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | poanas
# Processing Record 23 of Set 7 | weyburn
# Processing Record 24 of Set 7 | chimbote
# Processing Record 25 of Set 7 | kalabo
# Processing Record 26 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 7 | namatanai
# Processing Record 28 of Set 7 | luganville
# Processing Record 29 of Set 7 | sokolovo
# Processing Record 30 of Set 7 | la ronge
# Processing Record 31 of Set 7 | talnakh
# Processing Record 32 of Set 7 | igrim
# Processing Record 33 of Set 7 | lavrentiya
# Processing Record 34 of Set 7 | broome
# Processing Record 35 of Set 7 | scharbeutz
# Processing Record 36 of Set 7 | ulundi
# Processing Record 37 of Set 7 | plonsk
# Processing Record 38 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 7 | chapais
# Processing Record 40 of Set 7 | leh
# Processing Record 41 of Set 7 | bathsheba
# Processing Record 42 of Set 7 | kerteh
# City not found. Skipping...
# Processing Record 43 of Set 7 | tabory
# Processing Record 44 of Set 7 | hohhot
# Processing Record 45 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 7 | fukue
# Processing Record 47 of Set 7 | ancona
# Processing Record 48 of Set 7 | verkhnyaya inta
# Processing Record 49 of Set 7 | untsukul
# Processing Record 50 of Set 7 | cotacachi
# Processing Record 1 of Set 8 | moussoro
# Processing Record 2 of Set 8 | tanout
# Processing Record 3 of Set 8 | sehithwa
# Processing Record 4 of Set 8 | muros
# Processing Record 5 of Set 8 | ostersund
# Processing Record 6 of Set 8 | mapiripan
# Processing Record 7 of Set 8 | nagato
# Processing Record 8 of Set 8 | kyshtovka
# Processing Record 9 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 8 | college
# Processing Record 11 of Set 8 | monzon
# Processing Record 12 of Set 8 | tamandare
# Processing Record 13 of Set 8 | shimoda
# Processing Record 14 of Set 8 | rantepao
# Processing Record 15 of Set 8 | bonavista
# Processing Record 16 of Set 8 | arman
# Processing Record 17 of Set 8 | seoul
# Processing Record 18 of Set 8 | general roca
# Processing Record 19 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 8 | frolovo
# Processing Record 21 of Set 8 | abashiri
# Processing Record 22 of Set 8 | tura
# Processing Record 23 of Set 8 | pacific grove
# Processing Record 24 of Set 8 | broken hill
# Processing Record 25 of Set 8 | myaundzha
# Processing Record 26 of Set 8 | haines junction
# Processing Record 27 of Set 8 | guelengdeng
# City not found. Skipping...
# Processing Record 28 of Set 8 | sitka
# Processing Record 29 of Set 8 | springbok
# Processing Record 30 of Set 8 | payo
# Processing Record 31 of Set 8 | waingapu
# Processing Record 32 of Set 8 | bilma
# Processing Record 33 of Set 8 | lorengau
# Processing Record 34 of Set 8 | quatre cocos
# Processing Record 35 of Set 8 | puerto cabello
# Processing Record 36 of Set 8 | sainte-thecle
# Processing Record 37 of Set 8 | ossora
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | atakpame
# Processing Record 40 of Set 8 | abapo
# Processing Record 41 of Set 8 | galveston
# Processing Record 42 of Set 8 | gunjur
# Processing Record 43 of Set 8 | moerai
# Processing Record 44 of Set 8 | monte alegre de sergipe
# Processing Record 45 of Set 8 | yanliang
# Processing Record 46 of Set 8 | luena
# Processing Record 47 of Set 8 | kerouane
# Processing Record 48 of Set 8 | kabalo
# Processing Record 49 of Set 8 | olafsvik
# Processing Record 50 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 9 | lusambo
# Processing Record 2 of Set 9 | sungaipenuh
# Processing Record 3 of Set 9 | aloleng
# Processing Record 4 of Set 9 | mancio lima
# Processing Record 5 of Set 9 | saint-quentin
# Processing Record 6 of Set 9 | deniliquin
# Processing Record 7 of Set 9 | matara
# Processing Record 8 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 9 | shunyi
# Processing Record 10 of Set 9 | urengoy
# Processing Record 11 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 9 | havoysund
# Processing Record 13 of Set 9 | cayenne
# Processing Record 14 of Set 9 | san quintin
# Processing Record 15 of Set 9 | lokoja
# Processing Record 16 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 9 | villamontes
# Processing Record 18 of Set 9 | meulaboh
# Processing Record 19 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 9 | goderich
# Processing Record 21 of Set 9 | jieshi
# Processing Record 22 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 23 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 9 | port macquarie
# Processing Record 25 of Set 9 | margate
# Processing Record 26 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 27 of Set 9 | bilibino
# Processing Record 28 of Set 9 | antofagasta
# Processing Record 29 of Set 9 | port-cartier
# Processing Record 30 of Set 9 | guymon
# Processing Record 31 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 9 | clyde
# Processing Record 33 of Set 9 | solnechnyy
# Processing Record 34 of Set 9 | faya
# Processing Record 35 of Set 9 | mount gambier
# Processing Record 36 of Set 9 | kayes
# Processing Record 37 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 9 | leningradskiy
# Processing Record 39 of Set 9 | muroto
# Processing Record 40 of Set 9 | hervey bay
# Processing Record 41 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 9 | maltahohe
# Processing Record 43 of Set 9 | aljezur
# Processing Record 44 of Set 9 | vila franca do campo
# Processing Record 45 of Set 9 | lingao
# Processing Record 46 of Set 9 | shitanjing
# Processing Record 47 of Set 9 | los llanos de aridane
# Processing Record 48 of Set 9 | bahia blanca
# Processing Record 49 of Set 9 | rexburg
# Processing Record 50 of Set 9 | ixtapa
# Processing Record 1 of Set 10 | manokwari
# Processing Record 2 of Set 10 | paita
# Processing Record 3 of Set 10 | nanortalik
# Processing Record 4 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 5 of Set 10 | abbeville
# Processing Record 6 of Set 10 | marsh harbour
# Processing Record 7 of Set 10 | pangnirtung
# Processing Record 8 of Set 10 | flinders
# Processing Record 9 of Set 10 | nilakkottai
# Processing Record 10 of Set 10 | port hardy
# Processing Record 11 of Set 10 | bud
# Processing Record 12 of Set 10 | almeirim
# Processing Record 13 of Set 10 | richards bay
# Processing Record 14 of Set 10 | huilong
# Processing Record 15 of Set 10 | caribou
# Processing Record 16 of Set 10 | padang
# Processing Record 17 of Set 10 | pelagiada
# Processing Record 18 of Set 10 | hanmer springs
# Processing Record 19 of Set 10 | komsomolskiy
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | houma
# Processing Record 22 of Set 10 | xining
# Processing Record 23 of Set 10 | faanui
# Processing Record 24 of Set 10 | nyurba
# Processing Record 25 of Set 10 | balikpapan
# Processing Record 26 of Set 10 | portland
# Processing Record 27 of Set 10 | alta
# Processing Record 28 of Set 10 | karumbakkam
# Processing Record 29 of Set 10 | ulaangom
# Processing Record 30 of Set 10 | esso
# Processing Record 31 of Set 10 | nedryhayliv
# Processing Record 32 of Set 10 | canton
# Processing Record 33 of Set 10 | suzu
# City not found. Skipping...
# Processing Record 34 of Set 10 | chatham
# Processing Record 35 of Set 10 | daud khel
# Processing Record 36 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 10 | nouadhibou
# Processing Record 38 of Set 10 | honiara
# Processing Record 39 of Set 10 | ergani
# Processing Record 40 of Set 10 | kendari
# Processing Record 41 of Set 10 | yar-sale
# Processing Record 42 of Set 10 | brovary
# Processing Record 43 of Set 10 | bambanglipuro
# Processing Record 44 of Set 10 | obama
# Processing Record 45 of Set 10 | puerto madryn
# Processing Record 46 of Set 10 | asau
# Processing Record 47 of Set 10 | rafaela
# Processing Record 48 of Set 10 | pangai
# Processing Record 49 of Set 10 | orje
# Processing Record 50 of Set 10 | khandyga
# Processing Record 1 of Set 11 | podporozhye
# Processing Record 2 of Set 11 | saint anthony
# Processing Record 3 of Set 11 | huarmey
# Processing Record 4 of Set 11 | glendive
# Processing Record 5 of Set 11 | henties bay
# Processing Record 6 of Set 11 | zlatoust
# Processing Record 7 of Set 11 | garden city
# Processing Record 8 of Set 11 | neuquen
# Processing Record 9 of Set 11 | mudgee
# Processing Record 10 of Set 11 | puerto pinasco
# City not found. Skipping...
# Processing Record 11 of Set 11 | langres
# Processing Record 12 of Set 11 | bonthe
# Processing Record 13 of Set 11 | peterhead
# Processing Record 14 of Set 11 | dakar
# Processing Record 15 of Set 11 | yatou
# Processing Record 16 of Set 11 | kysyl-syr
# Processing Record 17 of Set 11 | fare
# Processing Record 18 of Set 11 | buenos aires
# Processing Record 19 of Set 11 | vychegodskiy
# Processing Record 20 of Set 11 | xinqing
# Processing Record 21 of Set 11 | alofi
# Processing Record 22 of Set 11 | ngama
# Processing Record 23 of Set 11 | nador
# Processing Record 24 of Set 11 | amos
# Processing Record 25 of Set 11 | ust-omchug
# Processing Record 26 of Set 11 | sulangan
# Processing Record 27 of Set 11 | sikasso
# Processing Record 28 of Set 11 | abu dhabi
# Processing Record 29 of Set 11 | camara de lobos
# Processing Record 30 of Set 11 | karachi
# Processing Record 31 of Set 11 | christchurch
# Processing Record 32 of Set 11 | kushiro
# Processing Record 33 of Set 11 | beloha
# Processing Record 34 of Set 11 | grindavik
# Processing Record 35 of Set 11 | togur
# Processing Record 36 of Set 11 | husavik
# Processing Record 37 of Set 11 | kamnik
# Processing Record 38 of Set 11 | quang ngai
# Processing Record 39 of Set 11 | thinadhoo
# Processing Record 40 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 11 | moose factory
# Processing Record 42 of Set 11 | timaru
# Processing Record 43 of Set 11 | okhotsk
# Processing Record 44 of Set 11 | pahrump
# Processing Record 45 of Set 11 | makakilo city
# Processing Record 46 of Set 11 | ucluelet
# Processing Record 47 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 11 | zhongshu
# Processing Record 49 of Set 11 | port hawkesbury
# Processing Record 50 of Set 11 | ngunguru
# Processing Record 1 of Set 12 | paamiut
# Processing Record 2 of Set 12 | madang
# Processing Record 3 of Set 12 | miri
# Processing Record 4 of Set 12 | binzhou
# Processing Record 5 of Set 12 | chalmette
# Processing Record 6 of Set 12 | hwange
# Processing Record 7 of Set 12 | mtimbira
# Processing Record 8 of Set 12 | sorland
# Processing Record 9 of Set 12 | olinda
# Processing Record 10 of Set 12 | dafeng
# Processing Record 11 of Set 12 | acapulco
# Processing Record 12 of Set 12 | rincon
# Processing Record 13 of Set 12 | bouca
# Processing Record 14 of Set 12 | mangrol
# Processing Record 15 of Set 12 | valparaiso
# Processing Record 16 of Set 12 | chingirlau
# Processing Record 17 of Set 12 | camana
# Processing Record 18 of Set 12 | matagami
# Processing Record 19 of Set 12 | port washington
# Processing Record 20 of Set 12 | kibala
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | kattivakkam
# Processing Record 23 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 12 | pipar
# Processing Record 25 of Set 12 | toora-khem
# Processing Record 26 of Set 12 | zhigansk
# Processing Record 27 of Set 12 | perth
# Processing Record 28 of Set 12 | muriti
# Processing Record 29 of Set 12 | southbridge
# Processing Record 30 of Set 12 | port blair
# Processing Record 31 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 12 | sakakah
# Processing Record 33 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 34 of Set 12 | heishan
# Processing Record 35 of Set 12 | tomatlan
# Processing Record 36 of Set 12 | nuuk
# Processing Record 37 of Set 12 | huanta
# Processing Record 38 of Set 12 | iberia
# Processing Record 39 of Set 12 | mosquera
# Processing Record 40 of Set 12 | tautira
# Processing Record 41 of Set 12 | silopi
# Processing Record 42 of Set 12 | burgeo
# Processing Record 43 of Set 12 | nemuro
# Processing Record 44 of Set 12 | angoram
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | rock sound
# Processing Record 47 of Set 12 | thai binh
# Processing Record 48 of Set 12 | acaponeta
# Processing Record 49 of Set 12 | akyab
# Processing Record 50 of Set 12 | kachug
# Processing Record 1 of Set 13 | hofn
# Processing Record 2 of Set 13 | mezen
# Processing Record 3 of Set 13 | buin
# Processing Record 4 of Set 13 | holme
# Processing Record 5 of Set 13 | evensk
# Processing Record 6 of Set 13 | tigil
# Processing Record 7 of Set 13 | praia da vitoria
# Processing Record 8 of Set 13 | itoman
# Processing Record 9 of Set 13 | cap malheureux
# Processing Record 10 of Set 13 | kirakira
# Processing Record 11 of Set 13 | tommot
# Processing Record 12 of Set 13 | anito
# Processing Record 13 of Set 13 | gardez
# Processing Record 14 of Set 13 | dunedin
# Processing Record 15 of Set 13 | turbat
# Processing Record 16 of Set 13 | haileybury
# Processing Record 17 of Set 13 | maceio
# Processing Record 18 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 13 | atka
# City not found. Skipping...
# Processing Record 20 of Set 13 | bitung
# Processing Record 21 of Set 13 | kupang
# Processing Record 22 of Set 13 | saint-francois
# Processing Record 23 of Set 13 | ostrovnoy
# Processing Record 24 of Set 13 | amarillo
# Processing Record 25 of Set 13 | bolitoc
# Processing Record 26 of Set 13 | halifax
# Processing Record 27 of Set 13 | grand gaube
# Processing Record 28 of Set 13 | umm lajj
# Processing Record 29 of Set 13 | wuan
# Processing Record 30 of Set 13 | asyut
# Processing Record 31 of Set 13 | kachiry
# Processing Record 32 of Set 13 | saurimo
# Processing Record 33 of Set 13 | krasnoselkup
# Processing Record 34 of Set 13 | koumac
# Processing Record 35 of Set 13 | codrington
# Processing Record 36 of Set 13 | villeta
# Processing Record 37 of Set 13 | tiznit
# Processing Record 38 of Set 13 | kaeo
# Processing Record 39 of Set 13 | mitu
# Processing Record 40 of Set 13 | tymovskoye
# Processing Record 41 of Set 13 | krasnogorskoye
# Processing Record 42 of Set 13 | san juan de arama
# Processing Record 43 of Set 13 | ahuimanu
# Processing Record 44 of Set 13 | tual
# Processing Record 45 of Set 13 | kakamega
# Processing Record 46 of Set 13 | marsaxlokk
# Processing Record 47 of Set 13 | killybegs
# Processing Record 48 of Set 13 | lethem
# Processing Record 49 of Set 13 | vysokogornyy
# Processing Record 50 of Set 13 | cockburn town
# Processing Record 1 of Set 14 | acajutla
# Processing Record 2 of Set 14 | manaus
# Processing Record 3 of Set 14 | vanavara
# Processing Record 4 of Set 14 | saint simons
# Processing Record 5 of Set 14 | santa cruz
# Processing Record 6 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 14 | salinopolis
# Processing Record 8 of Set 14 | dalinghe
# City not found. Skipping...
# Processing Record 9 of Set 14 | micheweni
# Processing Record 10 of Set 14 | katherine
# Processing Record 11 of Set 14 | nagireddipalle
# City not found. Skipping...
# Processing Record 12 of Set 14 | byron bay
# Processing Record 13 of Set 14 | xuanzhou
# Processing Record 14 of Set 14 | maubeuge
# Processing Record 15 of Set 14 | erzurum
# Processing Record 16 of Set 14 | bemidji
# Processing Record 17 of Set 14 | shubarkuduk
# Processing Record 18 of Set 14 | ina
# Processing Record 19 of Set 14 | aitape
# Processing Record 20 of Set 14 | barentu
# Processing Record 21 of Set 14 | sao joao da barra
# Processing Record 22 of Set 14 | rognan
# Processing Record 23 of Set 14 | manadhoo
# Processing Record 24 of Set 14 | ust-nera
# Processing Record 25 of Set 14 | cabedelo
# Processing Record 26 of Set 14 | liverpool
# Processing Record 27 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 14 | manzanillo
# Processing Record 29 of Set 14 | koslan
# Processing Record 30 of Set 14 | roald
# Processing Record 31 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 14 | yenagoa
# Processing Record 33 of Set 14 | escanaba
# Processing Record 34 of Set 14 | taga
# Processing Record 35 of Set 14 | omboue
# Processing Record 36 of Set 14 | nago
# Processing Record 37 of Set 14 | puerto del rosario
# Processing Record 38 of Set 14 | tessaoua
# Processing Record 39 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 40 of Set 14 | japura
# Processing Record 41 of Set 14 | pitimbu
# Processing Record 42 of Set 14 | yarim
# Processing Record 43 of Set 14 | anadyr
# Processing Record 44 of Set 14 | ariquemes
# Processing Record 45 of Set 14 | odesskoye
# Processing Record 46 of Set 14 | ust-kuyga
# Processing Record 47 of Set 14 | maraba
# Processing Record 48 of Set 14 | outlook
# Processing Record 49 of Set 14 | iraray
# Processing Record 50 of Set 14 | kinkala
# Processing Record 1 of Set 15 | kholmogory
# Processing Record 2 of Set 15 | angoche
# Processing Record 3 of Set 15 | okha
# Processing Record 4 of Set 15 | makokou
# Processing Record 5 of Set 15 | affoltern
# Processing Record 6 of Set 15 | shar
# Processing Record 7 of Set 15 | alice springs
# Processing Record 8 of Set 15 | ternate
# Processing Record 9 of Set 15 | marawi
# Processing Record 10 of Set 15 | grand forks
# Processing Record 11 of Set 15 | mogadishu
# Processing Record 12 of Set 15 | kambove
# Processing Record 13 of Set 15 | gogrial
# Processing Record 14 of Set 15 | whitehorse
# Processing Record 15 of Set 15 | nova petropolis
# Processing Record 16 of Set 15 | basoko
# Processing Record 17 of Set 15 | puerto baquerizo moreno
# Processing Record 18 of Set 15 | bumba
# Processing Record 19 of Set 15 | deulgaon raja
# Processing Record 20 of Set 15 | beian
# Processing Record 21 of Set 15 | shestakovo
# Processing Record 22 of Set 15 | alekseyevka
# Processing Record 23 of Set 15 | ishigaki
# Processing Record 24 of Set 15 | karakol
# Processing Record 25 of Set 15 | iralaya
# Processing Record 26 of Set 15 | arkhangelsk
# Processing Record 27 of Set 15 | gannan
# Processing Record 28 of Set 15 | peruibe
# Processing Record 29 of Set 15 | yangjiang
# Processing Record 30 of Set 15 | atambua
# Processing Record 31 of Set 15 | moultrie
# Processing Record 32 of Set 15 | znamenskoye
# Processing Record 33 of Set 15 | altay
# Processing Record 34 of Set 15 | burica
# City not found. Skipping...
# Processing Record 35 of Set 15 | vao
# Processing Record 36 of Set 15 | umarkot
# Processing Record 37 of Set 15 | durban
# Processing Record 38 of Set 15 | loa janan
# Processing Record 39 of Set 15 | gambiran
# Processing Record 40 of Set 15 | nanakuli
# Processing Record 41 of Set 15 | bara
# Processing Record 42 of Set 15 | viedma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 677

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Barrow  71.2906 -156.7887     30.22        80         100
# 1          Harper   4.3750   -7.7169     78.60        77          33
# 2         Panipat  29.3889   76.9681     77.90        73           0
# 3  Nuevo Progreso  23.1667  -97.9500     85.53        46           0
# 4    Longyearbyen  78.2186   15.6401     39.04        93         100
# 5            Ayan  56.4500  138.1667     35.96        57           0
# 6         Mataura -46.1927  168.8643     30.49        99           9
# 7         Rikitea -23.1203 -134.9692     73.53        78          88
# 8          Jawhar   2.7809   45.5005     76.68        75          21
# 9    Puerto Ayora  -0.7393  -90.3518     75.16        96          95
#
#    Wind Speed Country Current Description
# 0       10.36      US     overcast clouds
# 1        8.99      LR    scattered clouds
# 2        2.93      IN           clear sky
# 3        3.00      MX           clear sky
# 4        3.44      SJ                 fog
# 5       14.16      RU           clear sky
# 6        2.08      NZ           clear sky
# 7       15.70      PF          light rain
# 8       14.70      SO          few clouds
# 9        5.99      EC     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_names =['City','Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',\
       'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[column_names]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Barrow      US  71.2906 -156.7887     30.22        80         100
# 1          Harper      LR   4.3750   -7.7169     78.60        77          33
# 2         Panipat      IN  29.3889   76.9681     77.90        73           0
# 3  Nuevo Progreso      MX  23.1667  -97.9500     85.53        46           0
# 4    Longyearbyen      SJ  78.2186   15.6401     39.04        93         100
# 5            Ayan      RU  56.4500  138.1667     35.96        57           0
# 6         Mataura      NZ -46.1927  168.8643     30.49        99           9
# 7         Rikitea      PF -23.1203 -134.9692     73.53        78          88
# 8          Jawhar      SO   2.7809   45.5005     76.68        75          21
# 9    Puerto Ayora      EC  -0.7393  -90.3518     75.16        96          95
#
#    Wind Speed Current Description
# 0       10.36     overcast clouds
# 1        8.99    scattered clouds
# 2        2.93           clear sky
# 3        3.00           clear sky
# 4        3.44                 fog
# 5       14.16           clear sky
# 6        2.08           clear sky
# 7       15.70          light rain
# 8       14.70          few clouds
# 9        5.99     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
